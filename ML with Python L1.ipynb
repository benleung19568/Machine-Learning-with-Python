# %%
a='hello'
a
# Out:
# 'hello'

# %%
## list1.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
print(my_list)
print(my_list[1])
# Out:
# ['apple', 'banana', 'cherry', 'durian', 'egg']
# banana

# %%
## list2.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
print(my_list[-1])
# Out:
# egg

# %%
## list3.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
print(len(my_list))
# Out:
# 5

# %%
## list4.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
print(my_list)
my_list[0] = 'apricot'
print(my_list)
# Out:
# ['apple', 'banana', 'cherry', 'durian', 'egg']
# ['apricot', 'banana', 'cherry', 'durian', 'egg']

# %%
## list5.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
print(my_list[1:3])
print(my_list[2:3])
print(my_list[2:2])
print(my_list[2:])
print(my_list[:2])
print(my_list[:])
# Out:
# ['banana', 'cherry']
# ['cherry']
# []
# ['cherry', 'durian', 'egg']
# ['apple', 'banana']
# ['apple', 'banana', 'cherry', 'durian', 'egg']

# %%
## list6.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
print(my_list[-1:-3])
print(my_list[-3:-1])
print(my_list[-3:-2])
print(my_list[-3:-3])
print(my_list[-2:])
print(my_list[:-2])
# Out:
# []
# ['cherry', 'durian']
# ['cherry']
# []
# ['durian', 'egg']
# ['apple', 'banana', 'cherry']

# %%
## list7.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
print(my_list)
my_list.append('fruit')
print(my_list)
# Out:
# ['apple', 'banana', 'cherry', 'durian', 'egg']
# ['apple', 'banana', 'cherry', 'durian', 'egg', 'fruit']

# %%
## list9.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
print(my_list)
my_list.insert(1, 'apricot')
print(my_list)
# Out:
# ['apple', 'banana', 'cherry', 'durian', 'egg']
# ['apple', 'apricot', 'banana', 'cherry', 'durian', 'egg']

# %%
## list10.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg','ken']
print(my_list)
my_list.pop()
print(my_list)
my_list.remove("durian")
print(my_list)
del my_list[2]
print(my_list)
my_list.clear()
print(my_list)
# Out:
# ['apple', 'banana', 'cherry', 'durian', 'egg', 'ken']
# ['apple', 'banana', 'cherry', 'durian', 'egg']
# ['apple', 'banana', 'cherry', 'egg']
# ['apple', 'banana', 'egg']
# []

# %%
## list11.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
print(my_list)
for food in my_list:
    print("I like", food)
# Out:
# ['apple', 'banana', 'cherry', 'durian', 'egg']
# I like apple
# I like banana
# I like cherry
# I like durian
# I like egg

# %%
## list13.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
list2 = my_list
list2[0] = 'apricot'
print(my_list)
list3 = my_list.copy()
list3[2] = 'coconut'
print(my_list)
# Out:
# ['apricot', 'banana', 'cherry', 'durian', 'egg']
# ['apricot', 'banana', 'cherry', 'durian', 'egg']

# %%
## list14.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg']
my_list2 = [1,2,3]
my_list3 = [4,5,6]
my_list4 = my_list + my_list2
print(my_list4)
my_list4.extend(my_list3)
print(my_list4)
# Out:
# ['apple', 'banana', 'cherry', 'durian', 'egg', 1, 2, 3]
# ['apple', 'banana', 'cherry', 'durian', 'egg', 1, 2, 3, 4, 5, 6]

# %%
## list15.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg', 'apple','apples']
number_of_apple = my_list.count('apple')
print(number_of_apple)
my_list.reverse()
print (my_list)
# Out:
# 2
# ['apples', 'apple', 'egg', 'durian', 'cherry', 'banana', 'apple']

# %%
## list18.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg', 'apple','apples']
my_list.sort(reverse=True)
print(my_list)
my_list.sort(key=len)
print(my_list)
# Out:
# ['egg', 'durian', 'cherry', 'banana', 'apples', 'apple', 'apple']
# ['egg', 'apple', 'apple', 'durian', 'cherry', 'banana', 'apples']

# %%
## list20.py
def second(word):
    return word[1]
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg', 'apple','apples']
my_list.sort(key=second)
print(my_list)
# Out:
# ['banana', 'egg', 'cherry', 'apple', 'apple', 'apples', 'durian']

# %%
## list21.py
my_list = ['apple', 'banana', 'cherry', 'durian', 'egg', 'apple','apples']
my_list2 = my_list.copy()
my_list2.sort()
print(my_list, my_list2)
print(my_list, sorted(my_list))
# Out:
# ['apple', 'banana', 'cherry', 'durian', 'egg', 'apple', 'apples'] ['apple', 'apple', 'apples', 'banana', 'cherry', 'durian', 'egg']
# ['apple', 'banana', 'cherry', 'durian', 'egg', 'apple', 'apples'] ['apple', 'apple', 'apples', 'banana', 'cherry', 'durian', 'egg']

# %%
## tuple_vs_list3.py
my_list = ['first_thing', 'second_thing', 'third_thing']
my_list[1] = "new"
print(my_list[1])
my_tuple = ('first_thing', 'second_thing', 'third_thing')
my_tuple = list(my_tuple)
my_tuple[1] = "new"
print(my_tuple[1])
# Out:
# new
# new

# %%
## dictionary1.py
my_dictionary = {'one':'一', 'two':'二', 'three':'三'}
print(my_dictionary)
print(my_dictionary['one'])
# Out:
# {'one': '一', 'two': '二', 'three': '三'}
# 一

# %%
## dictionary2.py
my_dictionary = {'one':'一', 'two':'二', 'three':'三'}
for a,b in my_dictionary.items():
    print(a,b)## dictionary7.py
my_dictionary = {'one':'一', 'two':'二', 'three':'三'}
my_dictionary['one'] = 'yi'
print(my_dictionary)
my_dictionary.update({"two":"er", 'three':'san'})
print(my_dictionary)
# Out:
# one 一
# two 二
# three 三
# {'one': 'yi', 'two': '二', 'three': '三'}
# {'one': 'yi', 'two': 'er', 'three': 'san'}

# %%
## dictionary5.py
my_dictionary = {'one':'一', 'two':'二', 'three':'三'}
if "one" in my_dictionary:
    print("I find", my_dictionary["one"])
# Out:
# I find 一

# %%
## dictionary6.py
my_dictionary = {'one':'一', 'two':'二', 'three':'三'}
print(len(my_dictionary))
# Out:
# 3

# %%
## dictionary8.py
my_dictionary = {'one':'一', 'two':'二', 'three':'三'}
my_dictionary['four'] = '四'
print(my_dictionary)
# Out:
# {'one': '一', 'two': '二', 'three': '三', 'four': '四'}

# %%
## dictionary9.py
my_dictionary = {'one':'一', 'two':'二', 'three':'三', 'four':'四'}
my_dictionary.pop('one')
print(my_dictionary)
my_dictionary.popitem()
print(my_dictionary)
del my_dictionary['two']
print(my_dictionary)
my_dictionary.clear()
print(my_dictionary)
# Out:
# {'two': '二', 'three': '三', 'four': '四'}
# {'two': '二', 'three': '三'}
# {'three': '三'}
# {}

# %%
## dictionary10.py
my_dictionary = {'one':'一', 'two':'二', 'three':'三'}
x = my_dictionary.setdefault('four', 'si')
print(x)
y = my_dictionary.setdefault('one', 'yi')
print(y)
# Out:
# si
# 一

# %%
## dictionary11.py
my_key = ['one', 'two', 'three']
my_value = 0
my_dictionary = dict.fromkeys(my_key, my_value)
print(my_dictionary)
# Out:
# {'one': 0, 'two': 0, 'three': 0}

# %%
## set1.py
my_set = {'apple', 'banana', 'cherry', 'durian', 'egg'}
print(my_set)
# Out:
# {'apple', 'egg', 'banana', 'durian', 'cherry'}

# %%
## set2.py
my_set = {'apple', 'banana', 'cherry', 'durian', 'egg'}
for food in my_set:
    print(food)
# Out:
# apple
# egg
# banana
# durian
# cherry

# %%
my_set = {'apple', 'banana', 'cherry', 'durian', 'egg'}
my_set.update(['fruit'])
print(my_set)
my_set.update(['grape', 'grapefruit'])
print(my_set)
# Out:
# {'apple', 'egg', 'fruit', 'banana', 'durian', 'cherry'}
# {'grape', 'apple', 'egg', 'grapefruit', 'fruit', 'banana', 'durian', 'cherry'}

# %%
my_set = {'apple', 'banana', 'cherry', 'durian', 'egg'}
my_set.remove('banana')
print(my_set)
my_set.discard('cherry')
print(my_set)
my_set.pop()
print(my_set)
my_set.clear()
print(my_set)
# Out:
# {'apple', 'egg', 'durian', 'cherry'}
# {'apple', 'egg', 'durian'}
# {'egg', 'durian'}
# set()

# %%
## set11.py
my_set = {'apple', 'banana', 'cherry', 'durian', 'egg'}
my_set2 = {'apple', 'apple', 'apricot'}
my_set3 = {'fish'}
isdisjoint1 = my_set.isdisjoint(my_set2)
print(isdisjoint1)
isdisjoint2 = my_set.isdisjoint(my_set3)
print(isdisjoint2)
# Out:
# False
# True

# %%
import urllib.request

# %%
url = "http://httpbin.org/xml"
result = urllib.request.urlopen(url)
print("HTTP result code:", result.status)
# Out:
# HTTP result code: 200

# %%
result

# %%
url = "http://httpbin.org/xml"
result = urllib.request.urlopen(url)
print("HTTP result code:", result.status)
print("----- headers -----")
print(result.getheaders())
print("----- data -----")
print(result.read())
# Out:
# HTTP result code: 200
# ----- headers -----
# [('Date', 'Tue, 21 Mar 2023 11:25:32 GMT'), ('Content-Type', 'application/xml'), ('Content-Length', '522'), ('Connection', 'close'), ('Server', 'gunicorn/19.9.0'), ('Access-Control-Allow-Origin', '*'), ('Access-Control-Allow-Credentials', 'true')]
# ----- data -----
# b'<?xml version=\'1.0\' encoding=\'us-ascii\'?>\n\n<!--  A SAMPLE set of slides  -->\n\n<slideshow \n    title="Sample Slide Show"\n    date="Date of publication"\n    author="Yours Truly"\n    >\n\n    <!-- TITLE SLIDE -->\n    <slide type="all">\n      <title>Wake up to WonderWidgets!</title>\n    </slide>\n\n    <!-- OVERVIEW -->\n    <slide type="all">\n        <title>Overview</title>\n        <item>Why <em>WonderWidgets</em> are great</item>\n        <item/>\n        <item>Who <em>buys</em> WonderWidgets</item>\n    </slide>\n\n</slideshow>'

# %%
url = "http://httpbin.org/xml"
result = urllib.request.urlopen(url)
print("HTTP result code:", result.status)
print("----- headers -----")
print(result.getheaders())
print("----- data -----")
print(result.read().decode("utf-8"))
# Out:
# HTTP result code: 200
# ----- headers -----
# [('Date', 'Tue, 21 Mar 2023 11:28:32 GMT'), ('Content-Type', 'application/xml'), ('Content-Length', '522'), ('Connection', 'close'), ('Server', 'gunicorn/19.9.0'), ('Access-Control-Allow-Origin', '*'), ('Access-Control-Allow-Credentials', 'true')]
# ----- data -----
# <?xml version='1.0' encoding='us-ascii'?>
#
# <!--  A SAMPLE set of slides  -->
#
# <slideshow
#     title="Sample Slide Show"
#     date="Date of publication"
#     author="Yours Truly"
#     >
#
#     <!-- TITLE SLIDE -->
#     <slide type="all">
#       <title>Wake up to WonderWidgets!</title>
#     </slide>
#
#     <!-- OVERVIEW -->
#     <slide type="all">
#         <title>Overview</title>
#         <item>Why <em>WonderWidgets</em> are great</item>
#         <item/>
#         <item>Who <em>buys</em> WonderWidgets</item>
#     </slide>
#
# </slideshow>

# %%
import urllib.parse
url = "http://httpbin.org/get"
args = {"name":"Raymond","age":21}
data = urllib.parse.urlencode(args)
result = urllib.request.urlopen(url)
print("HTTP result code:", result.status)
print("----- return data -----")
print(result.read().decode("utf-8"))
# Out:
# HTTP result code: 200
# ----- return data -----
# {
#   "args": {},
#   "headers": {
#     "Accept-Encoding": "identity",
#     "Host": "httpbin.org",
#     "User-Agent": "Python-urllib/3.9",
#     "X-Amzn-Trace-Id": "Root=1-641995c7-75a314f01fc9f9e61698f8bf"
#   },
#   "origin": "34.69.221.55",
#   "url": "http://httpbin.org/get"
# }

# %%
url = "http://httpbin.org/post"
args = {
"name":"Raymond",
"age":21
}
data = urllib.parse.urlencode(args)
data = data.encode()
result = urllib.request.urlopen(url, data=data)
print("HTTP result code:",
result.status)
print("----- return data -----")
print(result.read().decode("utf-8"))
# Out:
# HTTP result code: 200
# ----- return data -----
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "age": "21",
#     "name": "Raymond"
#   },
#   "headers": {
#     "Accept-Encoding": "identity",
#     "Content-Length": "19",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "Python-urllib/3.9",
#     "X-Amzn-Trace-Id": "Root=1-641997c9-4b7f8e2843d15f24471f1cb6"
#   },
#   "json": null,
#   "origin": "34.69.221.55",
#   "url": "http://httpbin.org/post"
# }

# %%
from http import HTTPStatus
url = "http://httpbin.org/html"
result = urllib.request.urlopen(url)

try:
print("HTTP result code:", result.status)
if result.getcode() == HTTPStatus.OK:
    print("----- return data -----")
    print(result.read().decode("utf-8"))
# Out:
# HTTP result code: 200
# ----- return data -----
# <!DOCTYPE html>
# <html>
#   <head>
#   </head>
#   <body>
#       <h1>Herman Melville - Moby-Dick</h1>
#
#       <div>
#         <p>
# ...

# %%
import urllib.request
from http import HTTPStatus
from urllib.error import HTTPError
url = "http://httpbin.org/status/404"
try:
  result = urllib.request.urlopen(url)
  print("HTTP result code:{0}".format(result.status))
  if result.getcode() == HTTPStatus.OK:
      print("----- return data -----")
      print(result.read().decode("utf-8"))
except HTTPError as err:
  print("Error: {0}".format(err.code))
# Out:
# Error: 404

# %%
# %pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.4.0
# alabaster                     0.7.13
# albumentations                1.2.1
# altair                        4.2.2
# anyio                         3.6.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.15.1
# astropy                       5.2.1
# astunparse                    1.6.3
# atomicwrites                  1.4.1
# attrs                         22.2.0
# audioread                     3.0.0
# autograd                      1.5
# Babel                         2.12.1
# backcall                      0.2.0
# beautifulsoup4                4.11.2
# bleach                        6.0.0
# blis                          0.7.9
# bokeh                         2.4.3
# branca                        0.6.0
# bs4                           0.0.1
# CacheControl                  0.12.11
# ...

# %%
import requests

# %%
url = "http://httpbin.org/html"
result = requests.get(url)
print("Result code: {}".format(result.status_code))
print("----- headers -----")
print(result.headers)
print("----- content -----")
print(result.content)
# Out:
# Result code: 200
# ----- headers -----
# {'Date': 'Tue, 21 Mar 2023 12:13:27 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Content-Length': '3741', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# ----- content -----
# ...

# %%
## requests2.py
import requests
url = "http://httpbin.org/get"
dataValues = {
    "key1": "value1",
    "key2": "value2",
 }
result = requests.get(url,params = dataValues)
print("Result code:{0}".format(result.status_code))
print("----- headers -----")
print(result.headers)
print("----- content -----")
print(result.content)
# Out:
# Result code:200
# ----- headers -----
# {'Date': 'Tue, 21 Mar 2023 12:16:11 GMT', 'Content-Type': 'application/json', 'Content-Length': '376', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# ----- content -----
# b'{\n  "args": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.27.1", \n    "X-Amzn-Trace-Id": "Root=1-6419a008-453f5b995910f92e1026acab"\n  }, \n  "origin": "34.69.221.55", \n  "url": "http://httpbin.org/get?key1=value1&key2=value2"\n}\n'

# %%
## requests3.py
import requests
url = "http://httpbin.org/post"
dataValues = {
    "key1": "value1",
    "key2": "value2",}
result = requests.post(url,params = dataValues)
print("Result code:{0}".format(result.status_code))
print("----- headers -----")
print(result.headers)
print("----- content -----")
print(result.content)
# Out:
# Result code:200
# ----- headers -----
# {'Date': 'Tue, 21 Mar 2023 12:18:37 GMT', 'Content-Type': 'application/json', 'Content-Length': '468', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# ----- content -----
# b'{\n  "args": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "data": "", \n  "files": {}, \n  "form": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "0", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.27.1", \n    "X-Amzn-Trace-Id": "Root=1-6419a09c-38a0dc127df728f8710cb42e"\n  }, \n  "json": null, \n  "origin": "34.69.221.55", \n  "url": "http://httpbin.org/post?key1=value1&key2=value2"\n}\n'

# %%
## requests4.py
import requests
url = "http://httpbin.org/get"
headerValues = {
    "User-Agent": "Raymond/1.0",
}
result = requests.get(url, headers = headerValues)
print("Result code: {0}".format(result.status_code))
print("----- headers -----")
print(result.headers)
print("----- content -----")
print(result.content)
# Out:
# Result code: 200
# ----- headers -----
# {'Date': 'Tue, 21 Mar 2023 12:20:32 GMT', 'Content-Type': 'application/json', 'Content-Length': '294', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# ----- content -----
# b'{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "Raymond/1.0", \n    "X-Amzn-Trace-Id": "Root=1-6419a10f-4e305a0b06692bd658277775"\n  }, \n  "origin": "34.69.221.55", \n  "url": "http://httpbin.org/get"\n}\n'

# %%
# requests5.py
import requests
from requests import HTTPError
url = "http://httpbin.org/status/404"
try:
    result = requests.get(url)
    result.raise_for_status()
    print(result)
except HTTPError as err:
    print("Error: {0}".format(err))
# Out:
# Error: 404 Client Error: NOT FOUND for url: http://httpbin.org/status/404

# %%
## requests6.py
import requests
url = "http://httpbin.org/delay/0.5"
result = requests.get(url, timeout=3.0)
print(1, result.status_code)
url = "http://httpbin.org/delay/2.5"
result = requests.get(url, timeout=1.0)
print(2, result.status_code)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/local/lib/python3.9/dist-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /usr/local/lib/python3.9/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#
# /usr/lib/python3.9/http/client.py in getresponse(self)
#    1376             try:
# ...

# %%
# requests7.py
import requests
from requests import HTTPError, Timeout
url = "http://httpbin.org/delay/5"
try:
    result = requests.get(url, timeout = 2)
    result.raise_for_status()
    print(result)
except HTTPError as err:
    print("Error: {0}".format(err))
except Timeout as err:
    print("Timeout Error: {0}".format(err))
# Out:
# Timeout Error: HTTPConnectionPool(host='httpbin.org', port=80): Read timed out. (read timeout=2)

# %%
# requests8.py
import requests
from requests.auth import HTTPBasicAuth
url = "http://httpbin.org/basic-auth/raymond/password"
my_login = HTTPBasicAuth("raymond", "password") 
result = requests.get(url, auth = my_login)
print(result)
print(result.text)
# Out:
# <Response [200]>
# {
#   "authenticated": true,
#   "user": "raymond"
# }

# %%
# requests9.py
import requests
url = "http://github.com"
result = requests.get(url)
print(result.url)
print(result.history)
original = result.history.pop()
print(original)
print(original.url)
print(original.reason)
# Out:
# https://github.com/
# [<Response [301]>]
# <Response [301]>
# http://github.com/
# Moved Permanently

# %%
# requests10.py
import requests
url = "http://httpbin.org/cookies/set/sample/123456789"
session = requests.Session()
session.get(url)
result = session.get("https://httpbin.org/cookies")
print(result.text)
# Out:
# {
#   "cookies": {
#     "sample": "123456789"
#   }
# }

# %%
result = session.get("https://httpbin.org/cookies")
print(result.text)
# Out:
# {
#   "cookies": {
#     "sample": "123456789"
#   }
# }

# %%
# requests11.py
import requests
sess = requests.Session()
sess.headers.update({
"User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:68.0) Gecko/20100101 Firefox/68.0"
})
resp = sess.get("http://google.com")
print(len(resp.content))
sess.headers.update({"User-Agent": "Mozilla/5.0 (iPhone; CPU iPhone OS 13_1 like Mac OS X) AppleWebKit/605.1.15(KHTML, like Gecko) relesys_web_client/1.3.10.0 (RelesysApp/1.3.43net.relesysapp.nettoenterprise)"
})
resp = sess.get("http://google.com")
print(len(resp.content))
# Out:
# 133972
# 169277

# %%
# json1.py
import json
jsonData = '''{
    "firstname":"Raymond",
    "lastname":"Tsang",
    "email_work":
    "raymond@activeresco.com",
    "phone":null,
  "dateofbirth":"1997-07-01T00:00:00.000Z"
}'''
data = json.loads(jsonData)
print(data['firstname'])
# Out:
# Raymond

# %%
# json2.py
import json
pythonData = '''{
    "firstname":"Raymond",
    "lastname":"Tsang",

"email_work":"raymond@activeresco.com",
    "phone":null,
    "dateofbirth":"1997-07-01T00:00:00.000Z"
}'''
data = json.dumps(pythonData)
print(data)
# Out:
# "{\n    \"firstname\":\"Raymond\",\n    \"lastname\":\"Tsang\",\n\n\"email_work\":\"raymond@activeresco.com\",\n    \"phone\":null,\n    \"dateofbirth\":\"1997-07-01T00:00:00.000Z\"\n}"

# %%
# json3.py
import json
from json import JSONDecodeError
jsonData = '''{
    "firstname":"Raymond",
    "lastname":"Tsang",

"email_work":"raymond@activeresco.com",
    "phone":null,
    "dateofbirth":"1997-07-01T00:00:00.000Z"
}'''
try:
    data = json.loads(jsonData)
    print(data['firstname'])
except JSONDecodeError as err:
    print("json decode error")
    print(err.msg)
    print(err.lineno)
    print(err.colno)
# Out:
# Raymond

# %%
# json4.py
import requests
import json
url = "http://httpbin.org/json"
result = requests.get(url)
dataobj = result.json()
print(json.dumps(dataobj))
print(list(dataobj.keys()))
# Out:
# {"slideshow": {"author": "Yours Truly", "date": "date of publication", "slides": [{"title": "Wake up to WonderWidgets!", "type": "all"}, {"items": ["Why <em>WonderWidgets</em> are great", "Who <em>buys</em> WonderWidgets"], "title": "Overview", "type": "all"}], "title": "Sample Slide Show"}}
# ['slideshow']

# %%
# json5.py
import requests
import json
url = "http://httpbin.org/json"
result = requests.get(url)
dataobj = result.json()
print(json.dumps(dataobj))
print(list(dataobj.keys()))
print(dataobj['slideshow']['title'])
print("There are {0}slides".format(len(dataobj['slideshow']['slides'])))
# Out:
# {"slideshow": {"author": "Yours Truly", "date": "date of publication", "slides": [{"title": "Wake up to WonderWidgets!", "type": "all"}, {"items": ["Why <em>WonderWidgets</em> are great", "Who <em>buys</em> WonderWidgets"], "title": "Overview", "type": "all"}], "title": "Sample Slide Show"}}
# ['slideshow']
# Sample Slide Show
# There are 2slides

# %%
# json6.py
import requests
import json
url ="https://data.weather.gov.hk/weatherAPI/opendata/weather.php?dataType=fnd&lang=tc"
result = requests.get(url)
dataobj = result.json()
print(json.dumps(dataobj,ensure_ascii=False))
print(list(dataobj.keys()))
print(dataobj['generalSituation'])
print(dataobj['weatherForecast'][0]['forecastWeather'])
# Out:
# {"generalSituation": "偏南氣流會在未來一兩日為廣東沿岸帶來幾陣驟雨。預料一道低壓槽會在華中發展，並在本週後期移向華南沿岸，廣東地區天氣漸轉不穩定，驟雨逐漸增多及有狂風雷暴。受隨後的東北季候風影響，下週初沿岸地區天氣稍涼，仍然有雨。", "weatherForecast": [{"forecastDate": "20230322", "week": "星期三", "forecastWind": "南風4級。", "forecastWeather": "短暫時間有陽光，有一兩陣驟雨。早上沿岸有薄霧。", "forecastMaxtemp": {"value": 27, "unit": "C"}, "forecastMintemp": {"value": 23, "unit": "C"}, "forecastMaxrh": {"value": 95, "unit": "percent"}, "forecastMinrh": {"value": 70, "unit": "percent"}, "ForecastIcon": 54, "PSR": "低"}, {"forecastDate": "20230323", "week": "星期四", "forecastWind": "南風4級。", "forecastWeather": "短暫時間有陽光，有幾陣驟雨。稍後有一兩陣狂風雷暴。", "forecastMaxtemp": {"value": 27, "unit": "C"}, "forecastMintemp": {"value": 23, "unit": "C"}, "forecastMaxrh": {"value": 95, "unit": "percent"}, "forecastMinrh": {"value": 70, "unit": "percent"}, "ForecastIcon": 54, "PSR": "中低"}, {"forecastDate": "20230324", "week": "星期五", "forecastWind": "南至東南風4級。", "forecastWeather": "大致多雲，間中有驟雨及幾陣狂風雷暴。", "forecastMaxtemp": {"value": 26, "unit": "C"}
# ...

# %%
## homework_weatherForecast.py
import requests
import json
url ="https://data.weather.gov.hk/weatherAPI/opendata/weather.php?dataType=fnd&lang=tc"
result = requests.get(url)
dataobj = result.json()
for weatherForecast in dataobj['weatherForecast']:
    print(weatherForecast['week'], weatherForecast['forecastWeather'])
# Out:
# 星期三 短暫時間有陽光，有一兩陣驟雨。早上沿岸有薄霧。
# 星期四 短暫時間有陽光，有幾陣驟雨。稍後有一兩陣狂風雷暴。
# 星期五 大致多雲，間中有驟雨及幾陣狂風雷暴。
# 星期六 多雲，有驟雨及幾陣狂風雷暴。
# 星期日 多雲，間中有雨。
# 星期一 大致多雲，有幾陣雨。
# 星期二 大致多雲，有幾陣雨。
# 星期三 大致多雲，有幾陣雨。
# 星期四 大致多雲，有一兩陣雨。

# %%
pip install pygal_maps_world
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.8/270.8 KB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 10.1 MB/s eta 0:00:00
# ...
#   Created wheel for pygal_maps_world: filename=pygal_maps_world-1.0.2-py3-none-any.whl size=278555 sha256=d8c09823ac82103e2b7456b4b40bb668e39244132ade715a56c93c201c9af070
#   Stored in directory: /root/.cache/pip/wheels/f8/ff/bd/a3cb8647e19834039de7bfd2f9304e06d3314f87c135cb8b1a
# Successfully built pygal_maps_world
# ...

# %%
## json21.py
import pygal

# %%
from pygal.maps.world import COUNTRIES
for countryCode in COUNTRIES.keys():
print(countryCode, COUNTRIES[countryCode])
# Out:
#   File "<ipython-input-64-675810223890>", line 3
#     print(countryCode, COUNTRIES[countryCode])
#     ^
# IndentationError: expected an indented block

# %%
# %pip pygal.maps.world
import pygal.maps.world
path = 'c:/'
worldMap = pygal.maps.world.World()
worldMap.title = 'China'
worldMap.add('China',['cn'])
worldMap.render_to_file(path + 'worldmap01.svg')
# Out:
# ERROR: unknown command "pygal.maps.world"
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-66-01f17bcdf26d> in <module>
#       1 get_ipython().run_line_magic('pip', 'pygal.maps.world')
# ----> 2 import pygal.maps.world
#       3 path = 'c:/'
#       4 worldMap = pygal.maps.world.World()
#       5 worldMap.title = 'China'
#
# ModuleNotFoundError: No module named 'pygal.maps.world'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
