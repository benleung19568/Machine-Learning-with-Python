# %%
import pandas as pd

# %%
## pandas01.py
import pandas as pd
print(pd.__version__)
pd.show_versions()
# Out:
# 1.4.4
#
# INSTALLED VERSIONS
# ------------------
# commit           : ca60aab7340d9989d9428e11a51467658190bb6b
# python           : 3.9.16.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.10.147+
# Version          : #1 SMP Sat Dec 10 16:00:40 UTC 2022
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.4.4
# numpy            : 1.22.4
# pytz             : 2022.7.1
# dateutil         : 2.8.2
# setuptools       : 67.6.1
# pip              : 23.0.1
# Cython           : 0.29.34
# pytest           : 7.2.2
# hypothesis       : None
# sphinx           : 3.5.4
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : 4.9.2
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : 2.9.6
# jinja2           : 3.1.2
# IPython          : 7.34.0
# ...

# %%
import numpy as np

# %%
# pandas02.py
import pandas as pd
s = pd.Series()
print(s)
# Out:
# Series([], dtype: float64)
# <ipython-input-5-ae5772b48ff5>:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s = pd.Series()

# %%
# pandas03.py
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data)
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
# pandas04.py
import pandas as pd
import numpy as np
data = np.array(['a','b','c','d'])
s = pd.Series(data, index=[101,102,103,104])
print(s)
# Out:
# 101    a
# 102    b
# 103    c
# 104    d
# dtype: object

# %%
# pandas05.py
import pandas as pd
import numpy as np
data = {'a' : 0., 'b' : 1., 'c': 2.}
s = pd.Series(data)
print(s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
# pandas06.py
import pandas as pd
import numpy as np
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data,index=['b','c','d','a'])
print(s)
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %%
# pandas07.py
import pandas as pd
import numpy as np
s = pd.Series(10, index=[0, 1, 2, 3])
print(s)
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# dtype: int64

# %%
# pandas08.py
import pandas as pd
import numpy as np
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(s[1])
print(s[1:3])
print(s[1:])
print(s[:3])
# Out:
# 2
# b    2
# c    3
# dtype: int64
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
# pandas09.py
import pandas as pd
import numpy as np
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(s['b'])
print(s['b':'c'])
print(s['b':])
print(s[:'c'])
# Out:
# 2
# b    2
# c    3
# dtype: int64
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a    1
# b    2
# c    3
# dtype: int64

# %%
# pandas10.py
import pandas as pd
import numpy as np
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(s[['b']])
print(s[['b','c']])
# Out:
# b    2
# dtype: int64
# b    2
# c    3
# dtype: int64

# %%
# pandas11.py
import pandas as pd
import numpy as np
s = pd.Series([1,2,3,4,5],index = ['a','b','c','d','e'])
print(s['f'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'f'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# pandas21.py
import pandas as pd
df = pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# pandas22.py
import pandas as pd
data = [11,22,33,44,55]
df = pd.DataFrame(data)
print(df)
# Out:
#     0
# 0  11
# 1  22
# 2  33
# 3  44
# 4  55

# %%
# pandas23.py
import pandas as pd
data = [
['Ada',11],
['Ben',22],
['Cindy',33]
]
df = pd.DataFrame(data, columns=['Name','Age'])
print(df)
# Out:
#     Name  Age
# 0    Ada   11
# 1    Ben   22
# 2  Cindy   33

# %%
# pandas24.py
import pandas as pd
data = {
'Name':['Ada', 'Ben', 'Cindy'],
'Age': [11, 22, 33]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Ada   11
# 1    Ben   22
# 2  Cindy   33

# %%
# pandas25.py
import pandas as pd
data = {
'Name':['Ada', 'Ben', 'Cindy'],
'Age': [11, 22, 33]
}
df = pd.DataFrame(data, index=['A','B','C'])
print(df)
# Out:
#     Name  Age
# A    Ada   11
# B    Ben   22
# C  Cindy   33

# %%
# pandas26.py
import pandas as pd
data = [
{'a': 1, 'b': 2},
{'a': 5, 'b': 10, 'c': 20}
]
df = pd.DataFrame(data)
print(df)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
# pandas41.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print(s)
# Out:
# 0    1.624345
# 1   -0.611756
# 2   -0.528172
# 3   -1.072969
# dtype: float64

# %%
# pandas41.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print(s)
# Out:
# 0    1.624345
# 1   -0.611756
# 2   -0.528172
# 3   -1.072969
# dtype: float64

# %%
# pandas42.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print(s.values)
# Out:
# [ 1.62434536 -0.61175641 -0.52817175 -1.07296862]

# %%
# pandas43.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print(s.axes)
# Out:
# [RangeIndex(start=0, stop=4, step=1)]

# %%
# pandas44.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print('Empty list?', s.empty)
# Out:
# Empty list? False

# %%
# pandas45.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print('dimension: ', s.ndim)
# Out:
# dimension:  1

# %%
# pandas46.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print('size: ', s.size)
# Out:
# size:  4

# %%
# pandas47.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print(s.head(2))
# Out:
# 0    1.624345
# 1   -0.611756
# dtype: float64

# %%
# pandas48.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print(s.tail(2))
# Out:
# 2   -0.528172
# 3   -1.072969
# dtype: float64

# %%
# pandas48.py
import pandas as pd
import numpy as np
np.random.seed(1)
s = pd.Series(np.random.randn(4))
print(s.tail(3))
# Out:
# 1   -0.611756
# 2   -0.528172
# 3   -1.072969
# dtype: float64

# %%
# pandas51.py
import pandas as pd
d = {
'Name': pd.Series(['Ada','Ben','Cindy','Dave','Eddie','Frank','Gigi','Helen','Iris','Jack']),
'Marks':pd.Series([12,23,34,45,56,67,78,89,90,100])
}
df = pd.DataFrame(d)
print(df)
# Out:
#     Name  Marks
# 0    Ada     12
# 1    Ben     23
# 2  Cindy     34
# 3   Dave     45
# 4  Eddie     56
# 5  Frank     67
# 6   Gigi     78
# 7  Helen     89
# 8   Iris     90
# 9   Jack    100

# %%
df = pd.DataFrame(d)
print(df.sum())
# Out:
# Name     AdaBenCindyDaveEddieFrankGigiHelenIrisJack
# Marks                                           594
# dtype: object

# %%
df = pd.DataFrame(d)
print(df.mean())
# Out:
# Marks    59.4
# dtype: float64
# <ipython-input-33-e43bcb3c49da>:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(df.mean())

# %%
df = pd.DataFrame(d)
print(df.describe())
# Out:
#             Marks
# count   10.000000
# mean    59.400000
# std     30.368844
# min     12.000000
# 25%     36.750000
# 50%     61.500000
# 75%     86.250000
# max    100.000000

# %%
df = pd.DataFrame(d)
print(df.describe(include=['object']))
# Out:
#        Name
# count    10
# unique   10
# top     Ada
# freq      1

# %%
df = pd.DataFrame(d)
print(df.describe(include='all'))
# Out:
#        Name       Marks
# count    10   10.000000
# unique   10         NaN
# top     Ada         NaN
# freq      1         NaN
# mean    NaN   59.400000
# std     NaN   30.368844
# min     NaN   12.000000
# 25%     NaN   36.750000
# 50%     NaN   61.500000
# 75%     NaN   86.250000
# max     NaN  100.000000

# %%
# pandas58.py
import pandas as pd
import numpy as np
np.random.seed(1)
df = pd.DataFrame(np.random.randn(10,2), columns=['col1','col2'])
print(df)
# Out:
#        col1      col2
# 0  1.624345 -0.611756
# 1 -0.528172 -1.072969
# 2  0.865408 -2.301539
# 3  1.744812 -0.761207
# 4  0.319039 -0.249370
# 5  1.462108 -2.060141
# 6 -0.322417 -0.384054
# 7  1.133769 -1.099891
# 8 -0.172428 -0.877858
# 9  0.042214  0.582815

# %%
sorted_df=df.sort_values(by='col1')
print(sorted_df)
# Out:
#        col1      col2
# 1 -0.528172 -1.072969
# 6 -0.322417 -0.384054
# 8 -0.172428 -0.877858
# 9  0.042214  0.582815
# 4  0.319039 -0.249370
# 2  0.865408 -2.301539
# 7  1.133769 -1.099891
# 5  1.462108 -2.060141
# 0  1.624345 -0.611756
# 3  1.744812 -0.761207

# %%
sorted_df=df.sort_values(by='col1', ascending=False)
print(sorted_df)
# Out:
#        col1      col2
# 3  1.744812 -0.761207
# 0  1.624345 -0.611756
# 5  1.462108 -2.060141
# 7  1.133769 -1.099891
# 2  0.865408 -2.301539
# 4  0.319039 -0.249370
# 9  0.042214  0.582815
# 8 -0.172428 -0.877858
# 6 -0.322417 -0.384054
# 1 -0.528172 -1.072969
